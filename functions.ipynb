# %%
#basic function
def greet():
    print("Hello")
    print("Welcome to python")
greet()
# Out:
# Hello
# Welcome to python

# %%
#function without parameters
def welcome():
    print("Welcome to python")
welcome()
welcome()
welcome()

# %%
# function with parameter
def greet(name):
    print("Hello" , name)
greet("Lakshmi")
greet("bhanu")
